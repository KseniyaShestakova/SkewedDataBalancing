# %%
import matplotlib.pyplot as plt

# %%
f = open("dataset1_float", "r")
content = [float(item) for item in f.read().split(' ')[:-1]]
plt.hist(content, bins=100, density=True, alpha=0.4)
plt.show()

# %%
f = open("dataset1_int", "r")
content = [float(item) for item in f.read().split(' ')[:-1]]
plt.hist(content, bins=100, density=True, alpha=0.4)
plt.show()
